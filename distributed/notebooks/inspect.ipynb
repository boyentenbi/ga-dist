# %%
import matplotlib.pyplot as plt
import pandas
% matplotlib inline
ret_quartiles = pandas.read_csv('distributed/logs/1517424074/SkiingNoFrameskip-v4/log.csv').iloc[:,:5]

# with open('distributed/logs/1517424074/SkiingNoFrameskip-v4/log.csv', newline='\n') as csvfile:
#      reader = csv.DictReader(csvfile, delimiter=",", quotechar='|')

# %%
ret_quartiles.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>EpRetMax</th>
#       <th>EpRetParentMin</th>
#       <th>EpRetUQ</th>
#       <th>EpRetMed</th>
#       <th>EpRetLQ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-10526.0</td>
#       <td>-12273.0</td>
#       <td>-19539.75</td>
#       <td>-29953.0</td>
#       <td>-29982.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-9431.0</td>
#       <td>-11250.0</td>
#       <td>-16613.75</td>
#       <td>-18925.5</td>
#       <td>-23290.25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-8474.0</td>
#       <td>-10659.0</td>
#       <td>-16179.75</td>
# ...

# %%
ret_quartiles.plot()
